# %% [markdown]
# ### Import Libraries

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Random Number Ploting in Scatterplot

# %%
a=np.random.randint(15, size=(1, 25))
b=np.random.randint(100, size=(1, 25))

# %%
sns.scatterplot(x=a[0,], y=b[0,])

# %% [markdown]
# ### Take data from csv file

# %%
df=pd.read_csv("data/world-cup-comparisons/world_cup_comparisons.csv")

# %%
df.head()
# Out:
#            player  season       team  goals_z  xg_z  crosses_z  boxtouches_z  \
# 0  Cristian Pavón    2018  Argentina    -0.42 -0.55       0.08         -0.24
# 1  Eduardo Salvio    2018  Argentina    -0.42 -0.50      -0.51          0.64
# 2      Enzo Pérez    2018  Argentina    -0.42  0.11      -0.51         -0.69
# 3  Federico Fazio    2018  Argentina    -0.42 -0.59      -0.51         -0.69
# 4   Franco Armani    2018  Argentina    -0.42 -0.59      -0.51         -0.80
#
#    passes_z  progpasses_z  takeons_z  progruns_z  tackles_z  interceptions_z  \
# 0     -0.61         -0.72      -0.05        0.15       0.30            -0.79
# 1      0.02         -0.46      -0.05        0.48       0.61             0.67
# 2      0.27         -0.65      -0.36       -0.34       0.35            -0.22
# 3     -0.97         -0.91      -0.67       -0.84      -0.82            -0.79
# 4     -0.67          0.64      -0.67       -0.67      -0.82            -0.79
#
# ...

# %% [markdown]
# ### Count Plot

# %%
sns.countplot(x='season', data=df)

# %% [markdown]
# ### Scatter Plot

# %%
sns.scatterplot(x=df["season"], y=df["goals_z"])

# %% [markdown]
# ### Data set from Seaborn

# %%
t=sns.load_dataset("tips")
t.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x="total_bill", y="tip", data=t)

# %%
sns.scatterplot(x="total_bill", y="tip", data=t, hue="smoker")

# %%
hue_colors={"Yes":"black", "No":"red"}
sns.scatterplot(x="total_bill", y="tip", data=t, hue="smoker", palette=hue_colors)

# %% [markdown]
# # For more colors: https://htmlcolorcodes.com/

# %%
hue_colors={"Yes":"#6227B2", "No":"#D36ED2"}
sns.scatterplot(x="total_bill", y="tip", data=t, hue="smoker", palette=hue_colors)

# %%
sns.countplot(x="smoker", data=t)

# %%
sns.countplot(x="smoker", data=t, hue="sex", hue_order=["Female","Male"])

# %%
p=sns.load_dataset("titanic")
p.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.relplot(x="total_bill", y="tip", data=t, kind="scatter")

# %%
sns.relplot(x="total_bill", y="tip", data=t, kind="scatter", col="smoker")

# %%
sns.relplot(x="total_bill", y="tip", data=t, kind="scatter", row="smoker")

# %%
sns.relplot(x="total_bill", y="tip", data=t, kind="scatter", col="smoker", row="time")

# %%
sns.relplot(x="total_bill", y="tip", data=t, kind="scatter", col="day")

# %%
sns.relplot(x="total_bill", y="tip", data=t, kind="scatter", col="day",col_wrap=2)

# %%
sns.relplot(x="total_bill", y="tip", data=t, kind="scatter", col="day", col_wrap=2, col_order=["Thur", "Fri", "Sat", "Sun"])

# %%
sns.relplot(x="total_bill", y="tip", data=t, kind="scatter", size="size")

# %%
sns.relplot(x="total_bill", y="tip", data=t, kind="scatter", size="size", hue="size")

# %%
sns.relplot(x="total_bill", y="tip", data=t, kind="scatter", hue="smoker", style="smoker")

# %%
sns.relplot(x="total_bill", y="tip", data=t, kind="scatter", alpha=0.4)

# %%
t=sns.load_dataset("flights")
print(t.shape)
t.tail()
# Out:
# (144, 3)
#      year      month  passengers
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432

# %% [markdown]
# ### Creating new column

# %%
from datetime import date
t['date']=pd.to_datetime(t.year.astype(str) + '/' + t.month.astype(str) + '/01')
print(t)
# Out:
#      year      month  passengers       date
# 0    1949    January         112 1949-01-01
# 1    1949   February         118 1949-02-01
# 2    1949      March         132 1949-03-01
# 3    1949      April         129 1949-04-01
# 4    1949        May         121 1949-05-01
# ..    ...        ...         ...        ...
# 139  1960     August         606 1960-08-01
# 140  1960  September         508 1960-09-01
# 141  1960    October         461 1960-10-01
# 142  1960   November         390 1960-11-01
# 143  1960   December         432 1960-12-01
#
# [144 rows x 4 columns]

# %% [markdown]
# ### Using relplot

# %%
from pandas.plotting import register_matplotlib_converters
sns.relplot(x="year", y="passengers", data=t, kind="line")

# %%
sns.relplot(x="year", y="passengers", data=t, kind="line", hue="month")

# %%
sns.relplot(x="year", y="passengers", data=t, kind="line", hue="month", markers=True)

# %%
sns.relplot(x="year", y="passengers", data=t, kind="line", hue="month", dashes=False)

# %%
sns.relplot(x="year", y="passengers", data=t, kind="line", ci="sd")

# %%
sns.relplot(x="year", y="passengers", data=t, kind="line", ci=None)

# %% [markdown]
# ### New data set from Seaborn

# %%
t=sns.load_dataset("titanic")
print(t.shape)
t.head()
# Out:
# (891, 15)
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.countplot(x="sex", data=t)

# %% [markdown]
# ### Using catplot for countplot

# %%
sns.catplot(x="class", data=t, kind="count")

# %%
od=["Third", "Second", "First"]
sns.catplot(x="class", data=t, kind="count", order=od)

# %%
sns.catplot(x="class", data=t, kind="count", col="sex")

# %%
sns.catplot(x="class", y="adult_male", data=t, kind="bar")

# %%
sns.catplot(x="class", y="adult_male", data=t, kind="bar", ci=None)

# %%
sns.catplot(y="class", x="adult_male", data=t, kind="bar")

# %% [markdown]
# ### New data set from Seaborn

# %%
t=sns.load_dataset("tips")
t.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Using catplot for boxplot

# %%
sns.catplot(x="time", y="total_bill", data=t, kind="box")

# %%
sns.catplot(x="time", y="tip", data=t, kind="box")

# %%
sns.catplot(x="day", y="tip", data=t, kind="box", col="time")

# %%
sns.catplot(x="day", y="tip", data=t, kind="box", col="time", sym="")

# %%
sns.catplot(x="day", y="tip", data=t, kind="box", col="time", whis=2.0)

# %%
sns.catplot(x="day", y="tip", data=t, kind="box", col="time", whis=[5,95])

# %%
sns.catplot(x="day", y="tip", data=t, kind="box", col="time", whis=[0,100])

# %% [markdown]
# ### New data set from Seaborn

# %%
t=sns.load_dataset("titanic")
print(t.shape)
t.head()
# Out:
# (891, 15)
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### using catplot for pointplot

# %%
sns.catplot(x="class", y="age", data=t, kind="point")

# %%
sns.catplot(x="class", y="age", data=t, kind="point", hue="survived")

# %%
sns.catplot(x="class", y="age", data=t, kind="point", hue="survived", join=False)

# %%
from numpy import median

# %%
sns.catplot(x="class", y="age", data=t, kind="point", hue="survived", estimator=median)

# %% [markdown]
# if there is more outliyer then median is better

# %%
sns.catplot(x="class", y="age", data=t, kind="point", hue="survived", capsize=0.2)

# %%
sns.catplot(x="class", y="age", data=t, kind="point", hue="survived", ci=None)

# %%
sns.set_style("dark")
sns.catplot(x="class", y="age", data=t, kind="point", hue="survived")

# %%
sns.set_style("darkgrid")
sns.catplot(x="class", y="age", data=t, kind="point", hue="survived")

# %%
sns.set_style("whitegrid")
sns.catplot(x="class", y="age", data=t, kind="point", hue="survived")

# %%
sns.set_style("ticks")
sns.catplot(x="class", y="age", data=t, kind="point", hue="survived")

# %%
sns.set_style("white")
sns.catplot(x="class", y="age", data=t, kind="point", hue="survived")

# %%
sns.catplot(x="class", data=t, kind="count")

# %%
sns.set_palette("RdBu")
sns.catplot(x="class", data=t, kind="count")

# %%
sns.set_palette("RdBu_r")
sns.catplot(x="class", data=t, kind="count")

# %%
sns.set_palette("PRGn")
sns.catplot(x="class", data=t, kind="count")

# %%
sns.set_palette("PRGn_r")
sns.catplot(x="class", data=t, kind="count")

# %%
sns.set_palette("Greys")
sns.catplot(x="class", data=t, kind="count")

# %% [markdown]
# More Single Color Palettes: "Blues", "PuRd", "GnBu"

# %% [markdown]
# For reverse, use "_r" end of the paltters name.

# %%
custom_palette=["red", "green", "orange", "blue", "purple", "yellow"]
sns.set_palette(custom_palette)
sns.catplot(x="class", data=t, kind="count")

# %%
custom_palette=["#132498", "#F34923", "#324ABC", "#9A2FE2", "purple", "#67DD54"]
sns.set_palette(custom_palette)
sns.catplot(x="class", data=t, kind="count")

# %%
sns.set_context("talk")
sns.catplot(x="class", y="age", data=t, kind="point", hue="survived")

# %% [markdown]
# List of Context: "paper", "notebook", "talk", "poster"

# %%
sns.catplot(x="class", y="age", data=t, kind="box")

# %%
sns.set_context("paper")
g=sns.catplot(x="class", y="age", data=t, kind="box")
g.fig.suptitle("Kar kemon TK")
# Out:
# Text(0.5, 0.98, 'Kar kemon TK')

# %%
g=sns.catplot(x="class", y="age", data=t, kind="box")
g.fig.suptitle("Kar kemon TK", y=1.05)
plt.show()

# %%
type(g)
# Out:
# seaborn.axisgrid.FacetGrid

# %%
g=sns.catplot(x="class", y="age", data=t, kind="box", col="sex")
g.fig.suptitle("Kar kemon TK", y=1.05)
g.set_titles("This is {col_name}")
g.set(xlabel="Passenger's Class", ylabel="Passenger's Age")

plt.show()

# %%
g=sns.catplot(x="class", y="age", data=t, kind="box")
g.fig.suptitle("Kar kemon TK", y=1.05)
g.set(xlabel="Passenger's Class", ylabel="Passenger's Age")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Object Type: FaceGrid (ex: relpolt(), catplot()). How to Title: g.fig.subtitle()

# %% [markdown]
# Object Type: AxesSubplot (ex: scatterppolt(), countplot(), etc).  How to Title: g.set_title()
